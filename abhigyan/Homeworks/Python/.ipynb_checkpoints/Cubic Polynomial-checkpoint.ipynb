# %%
var('x,a,b,c,d')
# Out:
# (x, a, b, c, d)

# %%
f(x) = a*x^3+b*x^2+c*x+d

# %%
soln = f.solve(x)

# %%
for i in range(len(soln)):
    soln[i].show()
# Out:
# x == -1/18*(-I*sqrt(3) + 1)*(b^2/a^2 - 3*c/a)/(-1/27*b^3/a^3 + 1/6*b*c/a^2 - 1/2*d/a + 1/6*sqrt(-1/3*b^2*c^2 + 4/3*a*c^3 + 9*a^2*d^2 + 2/3*(2*b^3 - 9*a*b*c)*d)/a^2)^(1/3) - 1/2*(I*sqrt(3) + 1)*(-1/27*b^3/a^3 + 1/6*b*c/a^2 - 1/2*d/a + 1/6*sqrt(-1/3*b^2*c^2 + 4/3*a*c^3 + 9*a^2*d^2 + 2/3*(2*b^3 - 9*a*b*c)*d)/a^2)^(1/3) - 1/3*b/a
# x == -1/18*(I*sqrt(3) + 1)*(b^2/a^2 - 3*c/a)/(-1/27*b^3/a^3 + 1/6*b*c/a^2 - 1/2*d/a + 1/6*sqrt(-1/3*b^2*c^2 + 4/3*a*c^3 + 9*a^2*d^2 + 2/3*(2*b^3 - 9*a*b*c)*d)/a^2)^(1/3) - 1/2*(-I*sqrt(3) + 1)*(-1/27*b^3/a^3 + 1/6*b*c/a^2 - 1/2*d/a + 1/6*sqrt(-1/3*b^2*c^2 + 4/3*a*c^3 + 9*a^2*d^2 + 2/3*(2*b^3 - 9*a*b*c)*d)/a^2)^(1/3) - 1/3*b/a
# x == 1/9*(b^2/a^2 - 3*c/a)/(-1/27*b^3/a^3 + 1/6*b*c/a^2 - 1/2*d/a + 1/6*sqrt(-1/3*b^2*c^2 + 4/3*a*c^3 + 9*a^2*d^2 + 2/3*(2*b^3 - 9*a*b*c)*d)/a^2)^(1/3) + (-1/27*b^3/a^3 + 1/6*b*c/a^2 - 1/2*d/a + 1/6*sqrt(-1/3*b^2*c^2 + 4/3*a*c^3 + 9*a^2*d^2 + 2/3*(2*b^3 - 9*a*b*c)*d)/a^2)^(1/3) - 1/3*b/a

# %%
soln[2].rhs().imag_part()
# Out:
# 2/9*cos(-1/3*arctan2(-1/9*imag_part(a)^2*imag_part(b)^3*real_part(a)/(imag_part(a)^6 + 3*imag_part(a)^4*real_part(a)^2 + 3*imag_part(a)^2*real_part(a)^4 + real_part(a)^6) + 1/27*imag_part(b)^3*real_part(a)^3/(imag_part(a)^6 + 3*imag_part(a)^4*real_part(a)^2 + 3*imag_part(a)^2*real_part(a)^4 + real_part(a)^6) + 1/9*imag_part(a)^3*imag_part(b)^2*real_part(b)/(imag_part(a)^6 + 3*imag_part(a)^4*real_part(a)^2 + 3*imag_part(a)^2*real_part(a)^4 + real_part(a)^6) - 1/3*imag_part(a)*imag_part(b)^2*real_part(a)^2*real_part(b)/(imag_part(a)^6 + 3*imag_part(a)^4*real_part(a)^2 + 3*imag_part(a)^2*real_part(a)^4 + real_part(a)^6) + 1/3*imag_part(a)^2*imag_part(b)*real_part(a)*real_part(b)^2/(imag_part(a)^6 + 3*imag_part(a)^4*real_part(a)^2 + 3*imag_part(a)^2*real_part(a)^4 + real_part(a)^6) - 1/9*imag_part(b)*real_part(a)^3*real_part(b)^2/(imag_part(a)^6 + 3*imag_part(a)^4*real_part(a)^2 + 3*imag_part(a)^2*real_part(a)^4 + real_part(a)^6) - 1/27*imag_part(a)^3*real_part(b)^3/(imag_part(a)^6 + 3*i
# ...
