# %% [markdown]
# var('x,y')

# %%
r(x,y) = sqrt(x^2+y^2)

# %%
U(x,y) = (a/r(x,y))*e^(-1*b*r(x,y))

# %%
Ux(x,y)=U.derivative(x)

# %%
Uy(x,y)=U.derivative(y)

# %%
Ux.show()
Uy.show()
# Out:
# (x, y) |--> -a*b*x*e^(-sqrt(x^2 + y^2)*b)/(x^2 + y^2) - a*x*e^(-sqrt(x^2 + y^2)*b)/(x^2 + y^2)^(3/2)
# (x, y) |--> -a*b*y*e^(-sqrt(x^2 + y^2)*b)/(x^2 + y^2) - a*y*e^(-sqrt(x^2 + y^2)*b)/(x^2 + y^2)^(3/2)

# %%
plot(U(x,y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/abhigyan/anaconda3/envs/sage/lib/python3.7/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:6744)()
#     726         try:
# --> 727             ind = self._vars.index(var_name)
#     728         except ValueError:
#
# ValueError: 'x' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-7a59d8ec12e6> in <module>()
# ----> 1 plot(U(x,y))
#
# /home/abhigyan/anaconda3/envs/sage/lib/python3.7/site-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     491                 options['__original_opts'] = kwds
#     492             options.update(kwds)
# --> 493             return func(*args, **options)
# ...

# %% [markdown]
# I was able to figure out that the H(s) function should be of the form $\frac{A}{s-B}$, where $B \in \mathbb{R}^{-}$ and the ROC is $\Re \{s\} > B$.
