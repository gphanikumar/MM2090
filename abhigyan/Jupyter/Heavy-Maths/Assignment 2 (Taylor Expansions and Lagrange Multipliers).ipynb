# %%
var('x,y')
# Out:
# (x, y)

# %%
f(x,y) = (1-x-y+x*y)^(-1)

# %%
f.taylor((x,0),(y,0),2).show()
# Out:
# (x, y) |--> x^2 + x*y + y^2 + x + y + 1

# %%
f.taylor((x,0),(y,0),3).show()
# Out:
# (x, y) |--> x^3 + x^2*y + x*y^2 + y^3 + x^2 + x*y + y^2 + x + y + 1

# %%
g(x,y)=e^x*sin(y)

# %%
C(x,y)=g.taylor((x,0),(y,0),2)

# %%
E(x,y)=(-g(x,y)+C(x,y))

# %%
a = minimize_constrained(E,[(-0.1,-0.1),(0.1,0.1)],[0,0])

# %%
print(a)
# Out:
# (-0.1, 0.1)

# %%
E(a[0],a[1])
# Out:
# -0.00033301095242416895

# %%
t1=plot3d(g,(x,-1,1),(y,-1,1),color='purple')
t2=plot3d(C,(x,-1,1),(y,-1,1),color='cyan')

# %%
tn=t1+t2
tn.show()
# Out:
# Graphics3d Object

# %%
t3 = plot3d(E,(x,-0.1,0.1),(y,-0.1,0.1))

# %%
t3.show()
# Out:
# Graphics3d Object

# %%
plot3d(2*x^2-4*x+y^2-4*y+1,(x,0,1),(y,0,2),color='cyan')
# Out:
# Graphics3d Object
